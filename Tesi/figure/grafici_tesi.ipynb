# %%
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import math
c1 = '#1f77b4'
c1b = 'blue'
c2 = '#ff7f0e'
c2b = 'red'
gr = '#7f7f7f'

# %%
#Appartenenza a Numeri molto più grandi di 1
# %matplotlib inline
x=[-50,100]
y=[-0.006,-0.006]
x1=[102, 200]
y1=[0.994,0.994]
plt.step(x, y, color=c1, linewidth=2.5)
line_cyan, = plt.step(x1, y1, color=c1, label="Crisp", linewidth=2.5)
x1=[-50,5,100,200]
y1=[0.006,0.006,1.006,1.006]
line_orange, = plt.plot(x1,y1, color=c2, label="Fuzzy",linewidth=2.5)
plt.legend(handles=[line_cyan, line_orange])
plt.xlabel("Numeri Reali")
plt.ylabel("Grado di appartenenza")
plt.savefig("fuzzycrisp.pdf", bbox_inches = 'tight', pad_inches = 0)

# %%
#Appartenenza all'insieme Persone Giovani
# %matplotlib inline
def young(x):
    r = 2*math.exp((math.log(0.5)/50)*x) -1
    if r>0:
        return r
    else:
        return 0
x=np.array(range(0,70,2))
y=np.array(map(young,x))
plt.bar(x,y)
plt.xlabel("Eta\' in anni")
plt.ylabel("Grado di appartenenza")
plt.savefig("giovani.pdf", bbox_inches = 'tight', pad_inches = 0)

# %%
#Bevande tiepide
# %matplotlib inline
mu = 40
variance = 50
sigma = math.sqrt(variance)
x = np.linspace(0, 80, 500)
plt.plot(x,mlab.normpdf(x, mu, sigma)*15, color=c1, linewidth=3)
plt.xlabel("Gradi centigradi")
plt.ylabel("Grado di appartenenza")
plt.savefig("tiepide.pdf", bbox_inches = 'tight', pad_inches = 0)

# %%
#Margine svm
def produce1(n):
    x=[]
    y=[]
    i=0
    while(i<n):
        cx=10*np.random.random()
        cy=10*np.random.random()
        if(cy>cx+3.5):
            x.append(cx)
            y.append(cy)
            i=i+1
    return x, y
            
def produce2(n):
    x=[]
    y=[]
    i=0
    while(i<n):
        cx=10*np.random.random()
        cy=10*np.random.random()
        if(cy<cx-3.5):
            x.append(cx)
            y.append(cy)
            i=i+1
    return x, y
            
fig, ax = plt.subplots()  
s=60
plt.plot([0,10],[0,10], linewidth=3, color=gr)
plt.plot([0,10],[2,12], linewidth=1.5, color=gr)
plt.plot([0,10],[-2,8], linewidth=1.5, color=gr)
x1=[4.5]
y1=[6.5]
x2=[3.2]
y2=[1.2]
plt.scatter(x1,y1,color=c1, s=s)
plt.scatter(x2,y2,color=c2, s=s, marker="s")
x, y = produce1(15)
plt.scatter(x,y,color=c1, s=s)
x, y = produce2(15)
plt.scatter(x,y,color=c2, s=s, marker="s")
plt.xlim(-1,15)
#plt.arrow(4,6,-0.5,-2.5)
#plt.arrow(3.2,1.2,-1.2,+0.8)
#plt.text(2,-1.5,"y=x-1", fontsize=12)
#plt.text(7,10.5,"y=x+1", fontsize=12)
plt.text(10.5,9.5,"$wx + b = 0$", fontsize=12)
ax.axis('off')
plt.savefig("margine.pdf", bbox_inches = 'tight', pad_inches = 0)

# %%
#support vectors
fig, ax = plt.subplots()        
plt.plot([0,10],[0,10], linewidth=3, color=gr)
plt.plot([0,10],[2,12], linewidth=1.5, color=gr)
plt.plot([0,10],[-2,8], linewidth=1.5, color=gr)
x1=4.5
y1=6.5
x2=3.2
y2=1.2
plt.scatter(x1,y1,color=c1b, s=s)
plt.scatter(x2,y2,color=c2b, s=s, marker="s")
plt.scatter(x1+1.5,y1+1.5,color=c1b, s=s)
plt.scatter(x2+3,y2+3,color=c2b, s=s, marker="s")
x, y = produce1(15)
plt.scatter(x,y,color=c1, s=s)
x, y = produce2(12)
plt.scatter(x,y,color=c2, s=s, marker="s")
plt.xlim(-1,15)
#plt.arrow(4,6,-0.5,-2.5)
#plt.arrow(3.2,1.2,-1.2,+0.8)
#plt.text(2,-1.5,"y=x-1", fontsize=12)
#plt.text(7,10.5,"y=x+1", fontsize=12)
plt.text(10.5,9.5,"$wx + b = 0$", fontsize=12)
plt.text(10.5,11.5,"$wx + b = \gamma$", fontsize=12)
plt.text(10.5,7.5,"$wx + b = - \gamma$", fontsize=12)
ax.axis('off')
plt.savefig("supportvectors.pdf", bbox_inches = 'tight', pad_inches = 0)

# %%
#Margine svm
def produce3(n):
    x=[]
    y=[]
    i=0
    while(i<n):
        cx=10*np.random.random()
        cy=10*np.random.random()
        if(cy>cx+0.6):
            x.append(cx)
            y.append(cy)
            i=i+1
    return x, y
            
def produce4(n):
    x=[]
    y=[]
    i=0
    while(i<n):
        cx=10*np.random.random()
        cy=10*np.random.random()
        if(cy<=cx-0.6):
            x.append(cx)
            y.append(cy)
            i=i+1
    return x, y
            
fig, ax = plt.subplots()
plt.plot([0,10],[0,10], linewidth=3, color=gr)
x1=[7.3]
y1=[6.5]
x2=[3.2]
y2=[5]
plt.scatter(x1,y1,color=c1b, s=s)
plt.scatter(x2,y2,color=c2b, marker="s", s=s)
x, y = produce3(20)
plt.scatter(x,y,color=c1, s=s)
x, y = produce4(20)
plt.scatter(x,y,color=c2, marker="s", s=s)
plt.xlim(-1,15)
plt.text(10.5,9.5,"$wx + b = 0$", fontsize=12)

ax.axis('off')
plt.savefig("nonseparabili.pdf", bbox_inches = 'tight', pad_inches = 0)

# %%
fig, ax = plt.subplots()
plt.plot([-5,5],[0,0], linewidth=1, color='k')
plt.scatter([1,2,-1,-2],[0,0,0,0], marker='o', color=c1, s=s)
plt.scatter([3,4,-4,-3],[0,0,0,0], marker='s', color=c2, s=s)
plt.yticks([])
plt.savefig("mapping11.pdf", bbox_inches = 'tight', pad_inches = 0)

# %%
fig, ax = plt.subplots()
plt.plot([-5,5],[6.5,6.5], linewidth=3, color=gr)
plt.scatter([1,2,-1,-2],[1,4,1,4], marker='o', color=c1, s=s)
plt.scatter([3,4,-4,-3],[9,16,16,9], marker='s', color=c2, s=s)
plt.savefig("mapping12.pdf", bbox_inches = 'tight', pad_inches = 0)

# %%
fig, ax = plt.subplots()
plt.scatter([0,3,0,1.5,0],[3,0,0,0,1.5], marker='o', color=c1, s=s)
plt.scatter([1,2,1,2,1.5],[2,1,1,2,1.5], marker='s', color=c2, s=s)
plt.savefig("mapping21.pdf", bbox_inches = 'tight', pad_inches = 0)

# %%
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
xx, yy = np.meshgrid(range(4), range(4))
zz = np.zeros([4,4])
plt3d = plt.figure().gca(projection='3d')
plt3d.plot_surface(xx, yy, zz, alpha=0.2)
ax = plt.gca()
ax.hold(True)
xs = np.array([0,3,0,1.5,0])
ys = np.array([3,0,0,0,1.5])
zs = xs*ys
ax.scatter(xs, ys, zs, c=c1, s=s)
xs = np.array([1,2,2,1.5])
ys = np.array([2,1,2,1.5])
zs = xs*ys
ax.scatter(xs, ys, zs, zdir='z', c=c2, marker="s", s=s)
plt.savefig("mapping22.pdf", bbox_inches = 'tight', pad_inches = 0)
# Out:
# /Users/lucacermenati/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:9: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   if __name__ == '__main__':

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for c, z in zip(['y', c1, c2], [30, 20, 10, 0]):
    xs = np.arange(10)
    ys = np.random.rand(10)
    
    ax.bar(xs, ys, zs=z, zdir='y', color=c1, alpha=0.6)

ax.set_xlabel('$u$', fontsize=12)
ax.set_ylabel('$x$', fontsize=12)
ax.set_zlabel('$\mu_A(x,u)$', fontsize=12)
ax.w_yaxis.set_ticklabels(['','$x_1$','','','','','$x_2$','','$x_3$'])
ax.w_xaxis.set_ticklabels([0,0.2,0.4,0.6,0.8])

plt.savefig("fuzzy11.pdf", bbox_inches = 'tight', pad_inches = 0)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for c, z in zip([c1, c1, c2], [30, 20, 10, 0]):
    xs = np.arange(10)
    ys = np.random.rand(10)
    
    ax.bar(xs, ys, zs=z, zdir='y', color=c, alpha=0.6)

ax.set_xlabel('$u$', fontsize=12)
ax.set_ylabel('$x$', fontsize=12)
ax.set_zlabel('$\mu_A(x,u)$', fontsize=12)
ax.w_yaxis.set_ticklabels(['','$x_1$','','','','','$x_2$','','$x_3$'])
ax.w_xaxis.set_ticklabels([0,0.2,0.4,0.6,0.8])

plt.savefig("fuzzy12.pdf", bbox_inches = 'tight', pad_inches = 0)

# %%
#outliers
fig, ax = plt.subplots()        
plt.plot([0,10],[0,10], linewidth=3, color=gr)
plt.plot([0,10],[2,12], linewidth=1.5, color=gr)
plt.plot([0,10],[-2,8], linewidth=1.5, color=gr)
x1=4.5
y1=5.8
x2=3.2
y2=2.2
plt.scatter(x1,y1-2,color=c1, s=s)
plt.scatter(x2,y2+3,color=c2, s=s, marker="s")
plt.scatter(x1,y1,color=c1b, s=s)
plt.scatter(x2,y2,color=c2b, s=s, marker="s")
plt.scatter(x1+1.5,y1+1.5,color=c1b, s=s)
plt.scatter(x2+3,y2+3,color=c2b, s=s, marker="s")
x, y = produce1(15)
plt.scatter(x,y,color=c1, s=s)
x, y = produce2(12)
plt.scatter(x,y,color=c2, s=s, marker="s")
plt.xlim(-1,15)
#plt.arrow(4,6,-0.5,-2.5)
#plt.arrow(3.2,1.2,-1.2,+0.8)
#plt.text(2,-1.5,"y=x-1", fontsize=12)
#plt.text(7,10.5,"y=x+1", fontsize=12)
plt.text(10.5,9.5,"$wx + b = 0$", fontsize=12)
plt.text(10.5,11.5,"$wx + b = \gamma$", fontsize=12)
plt.text(10.5,7.5,"$wx + b = - \gamma$", fontsize=12)
ax.axis('off')
plt.savefig("outliers.pdf", bbox_inches = 'tight', pad_inches = 0)

# %%
#clustering

# %%
#clustering
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Make data
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)
x = 10 * np.outer(np.cos(u), np.sin(v))
y = 10 * np.outer(np.sin(u), np.sin(v))
z = 10 * np.outer(np.ones(np.size(u)), np.cos(v))

# Plot the surface
ax.plot_surface(x, y, z, color=gr, alpha=0.6)
x = np.linspace(-3, 3, 100)
y = x*x*10-80
ax.plot(x, y, zs=0, zdir='z', color=c1)
ax.plot([-3],[9],[0], color=c1, marker='o', label='cluster differente')
ax.plot([3],[9],[0], color=c1, marker='o')
stesso, = ax.plot([-2,2],[2,2],[-5,-5], color=c2, marker='o', label="stesso cluster")
ax.w_yaxis.set_ticklabels([])
ax.w_xaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
plt.legend(handles=[stesso, diverso])
plt.savefig("clustering.pdf", bbox_inches = 'tight', pad_inches = 0)
