# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
parentdir = os.path.dirname(parentdir)
sys.path.insert(0,parentdir)

# %%
import numpy as np
import matplotlib.cm as cm
import pandas as pd
from muzzifiers import *
from possibilearn.fuzzifiers import *
from possibilearn.kernel import GaussianKernel
import support_vector_fuzzifier as svf

source = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

iris_df = pd.read_csv(
    filepath_or_buffer=source,
    header=None,
    sep=',')

iris_df.columns=['sepal_len', 'sepal_wid', 'petal_len', 'petal_wid', 'class']
iris_df.dropna(how="all", inplace=True) # drops the empty line at file-end

iris_values = iris_df.iloc[:,:4].values #array dei soli valori
iris_labels = iris_df.iloc[:,4].values #array delle etichette

# %%
out_file = open("different_fuzzifiers_results_2.txt","w")
sigmas = np.linspace(0.2,0.3,5)
cs = np.array([10**i for i in range(-1,3)])

# %%
for (d,f) in [(d,f) for d in [2,3,4] for f in [CrispFuzzifier(), LinearFuzzifier(),
                                               QuantileConstantPiecewiseFuzzifier()]]:
            
    n=f.name+'_'+str(d)+'dim'
    results = svf.iterate_tests(iris_values, iris_labels, cs, sigmas, 10, dim=d, fuzzifier=f, name=n,
                               save_graph=True)
    out_file.write(svf.pretty_results(results))
    out_file.write('\n\n')
    
out_file.close()
# Out:
# holdout iteration 0
#
# model selection: trying parameters c=0.1, sigma=0.2
# starting clusterization
# clusters by index  [[3, 4, 5, 7, 9, 10, 16, 21, 31, 32, 33, 39, 42, 43, 47, 50, 52, 53, 56, 59, 60, 62, 66, 68, 75, 76, 80, 81, 82, 85, 86, 88, 95, 99, 100, 104, 110, 118], [0, 103, 41, 71, 17, 24, 29, 63], [14, 49, 18, 19, 54, 57, 25], [97, 36, 37, 73, 115, 22, 55], [106, 116, 101, 87], [1, 77, 111], [58, 84]]
# number of clusters  7
# inferring membership functions
# Unable to infer membership functions
#
# model selection: trying parameters c=1.0, sigma=0.2
# starting clusterization
# clusters by index  [[3, 4, 5, 7, 9, 10, 16, 21, 31, 32, 33, 39, 42, 43, 47, 50, 52, 53, 56, 59, 60, 62, 66, 68, 75, 76, 80, 81, 82, 85, 86, 88, 95, 99, 100, 110], [0, 103, 41, 71, 17, 24, 29, 63], [14, 49, 18, 19, 54, 57, 25], [97, 36, 37, 73, 115, 22, 55], [106, 116, 101, 87], [1, 77, 111], [58, 84]]
# number of clusters  7
# inferring membership functions
# associated labels ['Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-virginica']
# accuracy:  0.266666666667
#
# model selection: trying parameters c=10.0, sigma=0.2
# starting clusterization
# clusters by index  [[4, 5, 9, 10, 16, 31, 32, 33, 42, 43, 47, 50, 52, 53, 56, 62, 66, 68, 75, 76, 80, 81, 82, 86, 88, 95, 99, 100, 110], [0, 97, 36, 37, 71, 72, 41, 103, 73, 79, 112, 17, 115, 20, 22, 55, 24, 89, 29, 63], [14, 49, 18, 19, 54, 57, 25], [1, 77, 111], [3, 60, 7], [116, 101, 87], [58, 84]]
# number of clusters  7
# inferring membership functions
# associated labels ['Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica']
# accuracy:  0.4
#
# model selection: trying parameters c=100.0, sigma=0.2
# starting clusterization
# clusters by index  [[4, 5, 9, 10, 16, 31, 32, 33, 42, 43, 47, 50, 52, 53, 56, 59, 62, 66, 68, 75, 76, 80, 81, 82, 86, 88, 95, 99, 100, 110], [0, 103, 41, 71, 17, 24, 29, 63], [14, 49, 18, 19, 54, 57, 25], [97, 36, 37, 73, 115, 22, 55], [1, 77, 111], [3, 60, 7], [116, 101, 87], [58, 84]]
# number of clusters  8
# inferring membership functions
# associated labels ['Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-virginica', 'Iris-virginica']
# accuracy:  0.133333333333
#
# model selection: trying parameters c=0.1, sigma=0.225
# starting clusterization
# clusters by index  [[0, 103, 41, 17, 18, 25, 24, 89, 29], [66, 95, 76, 62, 31]]
# number of clusters  2
# inferring membership functions
# Unable to infer membership functions
#
# model selection: trying parameters c=1.0, sigma=0.225
# starting clusterization
# clusters by index  [[0, 103, 41, 17, 18, 25, 24, 89, 29], [66, 95, 76, 62, 31]]
# number of clusters  2
# inferring membership functions
# associated labels ['Iris-virginica', 'Iris-versicolor']
# accuracy:  0.466666666667
#
# model selection: trying parameters c=10.0, sigma=0.225
# starting clusterization
# clusters by index  [[0, 103, 41, 17, 18, 25, 24, 89, 29], [66, 95, 76, 62, 31]]
# number of clusters  2
# inferring membership functions
# associated labels ['Iris-virginica', 'Iris-versicolor']
# accuracy:  0.2
#
# model selection: trying parameters c=100.0, sigma=0.225
# starting clusterization
# clusters by index  [[66, 95, 76, 62, 31]]
# number of clusters  1
# inferring membership functions
# associated labels ['Iris-virginica']
# accuracy:  0.333333333333
#
# model selection: trying parameters c=0.1, sigma=0.25
# starting clusterization
# clusters by index  [[3, 4, 5, 7, 9, 10, 11, 21, 28, 30, 32, 34, 35, 39, 43, 45, 46, 47, 51, 58, 59, 60, 64, 67, 68, 75, 78, 84, 85, 87, 88, 90, 94, 99, 101, 102, 104, 105, 106, 107, 108, 109, 116, 118, 119], [0, 1, 14, 17, 18, 19, 22, 24, 25, 29, 36, 37, 41, 48, 49, 54, 55, 57, 70, 72, 77, 79, 83, 89, 92, 97, 111, 115], [66, 27, 76, 50, 16, 81, 82, 53, 86, 31, 62, 95]]
# number of clusters  3
# inferring membership functions
# Unable to infer membership functions
#
# model selection: trying parameters c=1.0, sigma=0.25
# starting clusterization
# clusters by index  [[32, 67, 4, 7, 75, 47, 118, 119], [50, 76, 53]]
# number of clusters  2
# inferring membership functions
# associated labels ['Iris-virginica', 'Iris-versicolor']
# accuracy:  0.266666666667
#
# model selection: trying parameters c=10.0, sigma=0.25
# starting clusterization
# clusters by index  [[50, 76, 53]]
# number of clusters  1
# inferring membership functions
# associated labels ['Iris-virginica']
# accuracy:  0.333333333333
#
# model selection: trying parameters c=100.0, sigma=0.25
# starting clusterization
# clusters by index  [[50, 76, 53]]
# number of clusters  1
# inferring membership functions
# associated labels ['Iris-virginica']
# accuracy:  0.333333333333
#
# model selection: trying parameters c=0.1, sigma=0.275
# starting clusterization
# clusters by index  [[4, 5, 7, 8, 9, 10, 11, 13, 16, 27, 28, 30, 31, 32, 33, 34, 35, 39, 40, 42, 43, 46, 47, 50, 51, 52, 53, 56, 58, 59, 60, 61, 62, 64, 65, 66, 67, 68, 74, 75, 76, 78, 80, 81, 82, 84, 86, 87, 88, 90, 94, 95, 99, 100, 101, 102, 104, 106, 107, 108, 109, 116, 117, 118, 119], [0, 1, 12, 15, 17, 20, 22, 24, 29, 36, 37, 41, 48, 55, 63, 70, 71, 72, 73, 77, 79, 83, 89, 92, 96, 97, 103, 111, 112, 115], [14, 49, 18, 19, 54, 57, 25]]
# number of clusters  3
# inferring membership functions
# Unable to infer membership functions
#
# model selection: trying parameters c=1.0, sigma=0.275
# starting clusterization
# clusters by index  [[7, 8, 9, 11, 13, 28, 30, 32, 34, 35, 40, 46, 47, 51, 58, 60, 64, 65, 67, 78, 84, 87, 90, 94, 101, 102, 104, 106, 107, 108, 109, 116, 117, 118, 119], [0, 1, 12, 15, 17, 20, 22, 24, 29, 36, 37, 41, 48, 55, 63, 70, 71, 72, 73, 77, 79, 83, 89, 92, 96, 97, 103, 111, 112, 115], [4, 16, 27, 31, 33, 42, 43, 50, 52, 53, 56, 61, 62, 66, 68, 74, 75, 76, 80, 81, 82, 86, 95, 99], [14, 49, 18, 19, 54, 57, 25]]
# number of clusters  4
# inferring membership functions
# associated labels ['Iris-virginica', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa']
# accuracy:  0.666666666667
#
# model selection: trying parameters c=10.0, sigma=0.275
# starting clusterization
# clusters by index  [[4, 5, 7, 8, 9, 10, 11, 13, 16, 27, 28, 30, 31, 32, 33, 34, 35, 39, 40, 42, 43, 46, 47, 50, 51, 52, 53, 56, 58, 59, 60, 61, 62, 64, 65, 66, 67, 68, 74, 75, 76, 78, 80, 81, 82, 84, 86, 87, 88, 90, 94, 95, 99, 100, 101, 102, 104, 106, 107, 108, 109, 116, 117, 118, 119], [0, 1, 12, 15, 17, 20, 22, 24, 29, 36, 37, 41, 48, 55, 63, 70, 71, 72, 73, 77, 79, 83, 89, 92, 96, 97, 103, 111, 112, 115], [14, 49, 18, 19, 54, 57, 25]]
# number of clusters  3
# inferring membership functions
# associated labels ['Iris-virginica', 'Iris-setosa', 'Iris-setosa']
# accuracy:  0.4
#
# model selection: trying parameters c=100.0, sigma=0.275
# starting clusterization
# clusters by index  [[4, 5, 7, 8, 9, 10, 11, 13, 16, 27, 28, 30, 31, 32, 33, 34, 35, 39, 40, 42, 43, 46, 47, 50, 51, 52, 53, 56, 58, 59, 60, 61, 62, 64, 65, 66, 67, 68, 74, 75, 76, 78, 80, 81, 82, 84, 86, 87, 88, 90, 94, 95, 99, 100, 101, 102, 104, 106, 107, 108, 109, 116, 117, 118, 119], [0, 1, 12, 15, 17, 20, 22, 24, 29, 36, 37, 41, 48, 55, 63, 70, 71, 72, 73, 77, 79, 83, 89, 92, 96, 97, 103, 111, 112, 115], [14, 49, 18, 19, 54, 57, 25]]
# number of clusters  3
# inferring membership functions
# associated labels ['Iris-virginica', 'Iris-setosa', 'Iris-setosa']
# accuracy:  0.6
#
# model selection: trying parameters c=0.1, sigma=0.3
# starting clusterization
# clusters by index  [[81, 66, 27, 52]]
# number of clusters  1
# inferring membership functions
# Unable to infer membership functions
#
# model selection: trying parameters c=1.0, sigma=0.3
# starting clusterization
# clusters by index  [[81, 66, 27, 52]]
# number of clusters  1
# inferring membership functions
# associated labels ['Iris-virginica']
# accuracy:  0.333333333333
#
# model selection: trying parameters c=10.0, sigma=0.3
# starting clusterization
# clusters by index  [[81, 66, 27, 52]]
# number of clusters  1
# inferring membership functions
# associated labels ['Iris-virginica']
# accuracy:  0.333333333333
#
# model selection: trying parameters c=100.0, sigma=0.3
# starting clusterization
# clusters by index  [[81, 66, 27, 52]]
# number of clusters  1
# inferring membership functions
# associated labels ['Iris-virginica']
# accuracy:  0.333333333333
#
# best couple (1.0, 0.275)
# clusters by index  [[128, 130, 3, 4, 134, 7, 9, 10, 11, 16, 131, 21, 27, 28, 30, 31, 32, 33, 34, 40, 42, 43, 44, 46, 47, 50, 51, 52, 53, 56, 58, 59, 61, 62, 64, 65, 66, 74, 75, 76, 78, 80, 81, 82, 84, 86, 87, 88, 90, 94, 95, 99, 100, 101, 102, 104, 106, 108, 109, 116, 117, 118, 119, 120, 121, 122, 123, 127], [0, 1, 12, 15, 17, 18, 20, 22, 24, 25, 29, 36, 37, 41, 48, 49, 55, 70, 72, 73, 77, 79, 83, 89, 92, 96, 97, 103, 111, 112, 115, 125, 126]]
# number of clusters  2
# inferring membership functions
# first clusters [[128, 130, 3, 4, 134, 7, 9, 10, 11, 16, 131, 21, 27, 28, 30, 31, 32, 33, 34, 40, 42, 43, 44, 46, 47, 50, 51, 52, 53, 56, 58, 59, 61, 62, 64, 65, 66, 74, 75, 76, 78, 80, 81, 82, 84, 86, 87, 88, 90, 94, 95, 99, 100, 101, 102, 104, 106, 108, 109, 116, 117, 118, 119, 120, 121, 122, 123, 127], [0, 1, 12, 15, 17, 18, 20, 22, 24, 25, 29, 36, 37, 41, 48, 49, 55, 70, 72, 73, 77, 79, 83, 89, 92, 96, 97, 103, 111, 112, 115, 125, 126]]
# associated labels ['Iris-virginica', 'Iris-setosa']
# test accuracy:  0.333333333333
# training accuracy:  0.518518518519
# iteration is valid
#
#
# holdout iteration 1
#
# model selection: trying parameters c=0.1, sigma=0.2
# starting clusterization
# clusters by index  [[0, 1, 3, 9, 12, 13, 16, 24, 35, 36, 43, 51, 56, 57, 61, 67, 70, 71, 76, 78, 84, 91, 94, 95, 100, 101, 102, 103, 105, 112, 115, 116], [6, 7, 14, 17, 26, 32, 40, 44, 48, 50, 53, 54, 63, 69, 73, 79, 81, 82, 83, 90, 93, 96, 108, 109, 118], [64, 99, 4, 5, 111, 80, 55, 88, 25, 58, 15, 29], [33, 2, 37, 97, 8, 41, 107, 66, 113, 31], [106, 68, 85]]
# number of clusters  5
# inferring membership functions
# Unable to infer membership functions
#
# model selection: trying parameters c=1.0, sigma=0.2
# starting clusterization
# clusters by index  [[0, 1, 3, 9, 12, 13, 16, 24, 35, 36, 43, 51, 56, 57, 61, 67, 70, 71, 76, 78, 84, 91, 94, 95, 100, 101, 102, 103, 105, 112, 115, 116], [6, 7, 14, 17, 26, 32, 40, 44, 48, 50, 53, 54, 63, 69, 73, 79, 81, 82, 83, 90, 93, 96, 108, 109, 118], [64, 99, 4, 5, 111, 80, 55, 88, 25, 58, 15, 29], [33, 2, 37, 97, 8, 41, 107, 66, 113, 31], [106, 68, 85]]
# number of clusters  5
# inferring membership functions
# associated labels ['Iris-versicolor', 'Iris-setosa', 'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor']
# accuracy:  0.466666666667
#
# model selection: trying parameters c=10.0, sigma=0.2
# starting clusterization
# clusters by index  [[0, 1, 3, 9, 12, 13, 16, 24, 35, 36, 43, 51, 56, 57, 61, 67, 70, 71, 76, 78, 84, 91, 94, 95, 100, 101, 102, 103, 105, 112, 115, 116], [6, 7, 14, 17, 26, 32, 40, 44, 48, 50, 53, 54, 63, 69, 73, 79, 81, 82, 83, 90, 93, 96, 108, 109, 118], [64, 99, 4, 5, 111, 80, 55, 88, 25, 58, 15, 29], [33, 2, 37, 97, 8, 41, 107, 66, 113, 31], [106, 68, 85]]
# number of clusters  5
# inferring membership functions
# associated labels ['Iris-versicolor', 'Iris-setosa', 'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor']
# accuracy:  0.6
#
# model selection: trying parameters c=100.0, sigma=0.2
# starting clusterization
# clusters by index  [[0, 1, 3, 9, 12, 13, 16, 24, 35, 36, 43, 51, 56, 57, 61, 67, 70, 71, 76, 78, 84, 91, 94, 95, 100, 101, 102, 103, 105, 112, 115, 116], [6, 7, 14, 17, 26, 32, 40, 44, 48, 50, 53, 54, 63, 69, 73, 79, 81, 82, 83, 90, 93, 96, 108, 109, 118], [64, 99, 4, 5, 111, 80, 55, 88, 25, 58, 15, 29], [33, 2, 37, 97, 8, 41, 107, 66, 113, 31], [106, 68, 85]]
# number of clusters  5
# inferring membership functions
# associated labels ['Iris-versicolor', 'Iris-setosa', 'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor']
# accuracy:  0.333333333333
#
# model selection: trying parameters c=0.1, sigma=0.225
# starting clusterization
# clusters by index  [[0, 1, 3, 9, 12, 13, 16, 20, 24, 43, 45, 51, 56, 57, 61, 67, 70, 71, 76, 78, 84, 91, 94, 95, 101, 103, 105, 115, 116], [7, 14, 17, 18, 23, 32, 44, 46, 54, 59, 63, 65, 73, 77, 79, 81, 82, 83, 90, 93, 96, 108, 118], [2, 4, 5, 8, 11, 15, 31, 33, 34, 37, 41, 47, 55, 58, 64, 66, 80, 97, 98, 99, 107, 113], [112, 100, 35, 36, 102], [106, 68, 85]]
# number of clusters  5
# inferring membership functions
# Unable to infer membership functions
#
# model selection: trying parameters c=1.0, sigma=0.225
# starting clusterization
# clusters by index  [[0, 1, 3, 9, 12, 13, 16, 20, 24, 43, 45, 51, 56, 57, 61, 67, 70, 71, 76, 78, 84, 91, 94, 95, 101, 103, 105, 115, 116], [7, 14, 17, 18, 23, 32, 44, 46, 54, 59, 63, 65, 73, 77, 79, 81, 82, 83, 90, 93, 96, 108, 118], [2, 4, 5, 8, 11, 15, 31, 33, 34, 37, 41, 47, 55, 58, 64, 66, 80, 97, 98, 99, 107, 113], [112, 100, 35, 36, 102], [106, 68, 85]]
# number of clusters  5
# inferring membership functions
# associated labels ['Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-virginica', 'Iris-versicolor']
# accuracy:  0.6
#
# model selection: trying parameters c=10.0, sigma=0.225
# starting clusterization
# clusters by index  [[0, 1, 3, 9, 12, 13, 16, 20, 24, 43, 45, 51, 56, 57, 61, 67, 70, 71, 76, 78, 84, 91, 94, 95, 101, 103, 105, 115, 116], [7, 14, 17, 18, 23, 32, 44, 46, 54, 59, 63, 65, 73, 77, 79, 81, 82, 83, 90, 93, 96, 108, 118], [2, 4, 5, 8, 11, 15, 31, 33, 34, 37, 41, 47, 55, 58, 64, 66, 80, 97, 98, 99, 107, 113], [112, 100, 35, 36, 102], [106, 68, 85]]
# number of clusters  5
# inferring membership functions
# associated labels ['Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-virginica', 'Iris-versicolor']
# accuracy:  0.666666666667
#
# model selection: trying parameters c=100.0, sigma=0.225
# starting clusterization
# clusters by index  [[0, 1, 3, 9, 12, 13, 16, 20, 24, 43, 45, 51, 56, 57, 61, 67, 70, 71, 76, 78, 84, 91, 94, 95, 101, 103, 105, 115, 116], [7, 14, 17, 18, 23, 26, 32, 40, 44, 46, 50, 53, 54, 59, 63, 65, 69, 73, 77, 79, 81, 82, 83, 90, 93, 96, 108, 118], [64, 33, 2, 99, 37, 8, 41, 11, 66, 80, 113, 107, 55, 31], [112, 100, 35, 36, 102], [106, 68, 85]]
# number of clusters  5
# inferring membership functions
# associated labels ['Iris-versicolor', 'Iris-setosa', 'Iris-virginica', 'Iris-virginica', 'Iris-versicolor']
# accuracy:  0.6
#
# model selection: trying parameters c=0.1, sigma=0.25
# starting clusterization

# %%
results
